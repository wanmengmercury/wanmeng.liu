# %%
p1 = '''Built an agentic workflow application with an orchestration agent and two subagents for document search tasks and text-to-SQL tasks.
Built an orchestration agent that accepts natural language questions regarding a provider performance database with 3 tables and identifies the user's intent.
Built subagents for the orchestration agent to answer questions based on the intent. One of the subagents was given a tool that picks the relevant knowledge base, another tool that retrieves from individual knowledge bases, and another tool that summarizes the retrieved texts from the previous tool and provides a final answer.
Built a text-to-SQL subagent with the following capabilities: accepting natural language questions, invoking tools that write different SQL code snippets for different clauses, and returning SQL in compliance with business and database logic. The text-to-SQL subagent also has a data visualization tool for questions that require the usage of geographic data so that the user can see a choropleth.
Built a GEPA-based prompt tuning pipeline for the text-to-SQL subagent's tool prompts with a scoring metric based on cosine similarity between llm-generated and gold SQL snippets. Designed a human-in-the-loop data expansion process that grew training data from 20 seed examples per tool by generating candidates with the tuned prompt and labeling them before the next GEPA run.
Enhanced the automated evaluation framework by designing a composite metric that scored the LLM judge on both grade correctness and semantic similarity of its reasoning to a hand-curated ground truth, then used GEPA to optimize the judge's prompt against this metric.
Rewrote the frontend HTML and CSS to comply with the client's branding requirements while preserving existing functionality for prompt input, result display, and session management.
Removed all AWS Bedrock and S3 dependencies from the backend and replaced them with Snowflake Cortex and Container Services to comply with the client’s environment requirements. 
Supported the DevOps team to deploy to Snowflake Container Services and to higher environments.
'''.split('\n')
p1_all = ''
for line in p1:
    tmp = f"<li>{line}</li>\n"
    p1_all += tmp
print(p1_all)
# Out:
# <li>Built an agentic workflow application with an orchestration agent and two subagents for document search tasks and text-to-SQL tasks.</li>
# <li>Built an orchestration agent that accepts natural language questions regarding a provider performance database with 3 tables and identifies the user's intent.</li>
# <li>Built subagents for the orchestration agent to answer questions based on the intent. One of the subagents was given a tool that picks the relevant knowledge base, another tool that retrieves from individual knowledge bases, and another tool that summarizes the retrieved texts from the previous tool and provides a final answer.</li>
# ...

# %%
p1 = '''Conducted regression analysis and statistical tests on state of Georgia Covid-19 data from March 2020 to June 2021 to study associations between socioeconomic factors and Covid-19 cases, deaths, hospitalizations and vaccination rates
Visualized Covid-19 hotspots and trends in 159 counties in Georgia by Developing 30+ interactive maps and 50+ temporal plots with Seaborn, Matplotlib, and Plotly
Delivered scientific reports and presentations to communicate results of statistical modeling and policy implications with audience from both technical and non-technical backgrounds'''.split('\n')
p1_all = ''
for line in p1:
    tmp = f"<li>{line}</li>\n"
    p1_all += tmp
print(p1_all)
# Out:
# <li>Conducted regression analysis and statistical tests on state of Georgia Covid-19 data from March 2020 to June 2021 to study associations between socioeconomic factors and Covid-19 cases, deaths, hospitalizations and vaccination rates</li>
# <li>Visualized Covid-19 hotspots and trends in 159 counties in Georgia by Developing 30+ interactive maps and 50+ temporal plots with Seaborn, Matplotlib, and Plotly</li>
# <li>Delivered scientific reports and presentations to communicate results of statistical modeling and policy implications with audience from both technical and non-technical backgrounds</li>

# %%
p1 = '''Built a text-to-SQL agent — orchestrating workflows, tools, subagents, few shot examples — accepting natural language questions regarding a claims database with 15 tables and returning SQL in compliance with business and database logic. The agent also had query corrector and data analyzer to answer user questions in natural language. 
Added guardrails for access control using regex on agent-generated SQL. 
Improved agent latency by many optimization techniques such as parallel processing, token optimization, reducing usage of subagent (ReAct) and LLM. 
Built automated evaluation framework using LLM and manually-created examples of ground truths testing set. Built evaluation dashboard to track consistency, latency, and accuracy of the agent using this framework. User feedback is also added to the dashboard. Achieved 85% accuracy and 90% consistency during evaluation.
Deployed the agent in dev EC2 and exposed it as a Fast API. Also, built a frontend with Streamlit, html, and css for user login, authentication, inputting prompt, calling the deployed API backend, displaying the results, and maintaining session. Later supported DevOps team to deploy in higher environments including production environments.'''.split('\n')
p1_all = ''
for line in p1:
    tmp = f"<li>{line}</li>\n"
    p1_all += tmp
print(p1_all)
# Out:
# <li>Built a text-to-SQL agent — orchestrating workflows, tools, subagents, few shot examples — accepting natural language questions regarding a claims database with 15 tables and returning SQL in compliance with business and database logic. The agent also had query corrector and data analyzer to answer user questions in natural language. </li>
# <li>Added guardrails for access control using regex on agent-generated SQL. </li>
# <li>Improved agent latency by many optimization techniques such as parallel processing, token optimization, reducing usage of subagent (ReAct) and LLM. </li>
# <li>Built automated evaluation framework using LLM and manually-created examples of ground truths testing set. Built evaluation dashboard to track consistency, latency, and accuracy of the agent using this framework. User feedback is also added to the dashboard. Achieved 85% accuracy and 90% consistency during evaluation.</li>
# ...

# %%
p1 = '''Preprocessed data with variable transformation and missing value removal with Numpy and Pandas
Employed random forest, logistic regression, support vector machine models with Scikit-learn to show whether home court effects were different in pre-pandemic and post-pandemic games and to quantify the change in the strength of each team in each year from 2003 to 2020
Tuned models utilizing grid search cross-validation with Scikit-learn and selected the optimized model with 85% accuracy '''.split('\n')
p1_all = ''
for line in p1:
    tmp = f"<li>{line}</li>\n"
    p1_all += tmp
print(p1_all)
# Out:
# <li>Preprocessed data with variable transformation and missing value removal with Numpy and Pandas</li>
# <li>Employed random forest, logistic regression, support vector machine models with Scikit-learn to show whether home court effects were different in pre-pandemic and post-pandemic games and to quantify the change in the strength of each team in each year from 2003 to 2020</li>
# <li>Tuned models utilizing grid search cross-validation with Scikit-learn and selected the optimized model with 85% accuracy </li>
