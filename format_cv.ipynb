# %%
p1 = '''Architected and deployed end-to-end text-to-SQL agentic system as lead engineer — orchestrating model inference, retrieval, and structured reasoning (LangChain, LangGraph, DSPy) to replace rule-based analyst workflows with learned evaluation, achieving ~85% accuracy where the incumbent vendor solution scored ~20%
Built master routing agent coordinating document retrieval, SQL generation, and guardrails into a unified application serving dual audiences: business users who need answers and analysts who need accelerated SQL
Developed meta-evaluation methodology (evaluation-of-evaluation): SQL judge and GEPA prompt optimization framework to systematically verify evaluator correctness, reducing evaluation cycles from 2–3 hours to 20 minutes
Built golden-set benchmarks and iterative calibration loops by curating golden reference query sets, instrumenting experiment tracking across prompt and tooling variations, and running A/B comparisons to isolate accuracy drivers
Decomposed complex inference into discrete, debuggable decision points with self-correcting query mechanism; parallelized retrieval reducing response time to <20 seconds versus hours for human analysts
Led full-stack migration from AWS (Bedrock, Knowledge Base, S3, Athena) to Snowflake-native architecture (Cortex LLM, Cortex Search, embedding models), resolving organizational deadlock on compliance requirements
Shipped full-stack application (Python backend, Streamlit frontend) — engineered production-grade UI through custom HTML/CSS injection and original design work, delivering a polished interface indistinguishable from dedicated frontend engineering without a frontend engineer or designer on the team'''.split('\n')
p1_all = ''
for line in p1:
    tmp = f"<li>{line}</li>\n"
    p1_all += tmp
print(p1_all)
# Out:
# <li>Architected and deployed end-to-end text-to-SQL agentic system as lead engineer — orchestrating model inference, retrieval, and structured reasoning (LangChain, LangGraph, DSPy) to replace rule-based analyst workflows with learned evaluation, achieving ~85% accuracy where the incumbent vendor solution scored ~20%</li>
# <li>Built master routing agent coordinating document retrieval, SQL generation, and guardrails into a unified application serving dual audiences: business users who need answers and analysts who need accelerated SQL</li>
# <li>Developed meta-evaluation methodology (evaluation-of-evaluation): SQL judge and GEPA prompt optimization framework to systematically verify evaluator correctness, reducing evaluation cycles from 2–3 hours to 20 minutes</li>
# ...

# %%
p1 = '''Designed novel fraud detection methodology proving group-level upcoding patterns could be identified from incomplete claims data — reframing a problem the industry considers blocked by insufficient clinical detail
Built end-to-end inference pipeline: vectorized patient event sequences, applied k-means clustering to surface 3 distinct admission patterns, and developed LLM agent to translate statistical clusters into actionable narratives
~30% of admissions flagged as "unlikely sepsis"; independent audit by a major insurance company validated findings through manual chart review of 100 hospitals, recovering $1.8M
Sole technical contributor across the full pipeline — event tables, clustering, agent development, pattern interpretation'''.split('\n')
p1_all = ''
for line in p1:
    tmp = f"<li>{line}</li>\n"
    p1_all += tmp
print(p1_all)
# Out:
# <li>Designed novel fraud detection methodology proving group-level upcoding patterns could be identified from incomplete claims data — reframing a problem the industry considers blocked by insufficient clinical detail</li>
# <li>Built end-to-end inference pipeline: vectorized patient event sequences, applied k-means clustering to surface 3 distinct admission patterns, and developed LLM agent to translate statistical clusters into actionable narratives</li>
# <li>~30% of admissions flagged as "unlikely sepsis"; independent audit by a major insurance company validated findings through manual chart review of 100 hospitals, recovering $1.8M</li>
# <li>Sole technical contributor across the full pipeline — event tables, clustering, agent development, pattern interpretation</li>

# %%
p1 = '''Designed platform-agnostic agent architecture with abstraction layers for LLM providers (Bedrock, Cortex), data sources (S3, Snowflake Stage, Athena), and deployment targets (EC2, Snowflake containers) — codebase adopted as the baseline for two subsequent production systems without re-architecture
Mentored team on building for enterprise volatility: how to design modular systems that absorb changing platform mandates, requirements, and deployment constraints rather than requiring rewrites
Own all technical hiring for the GenAI team: designed Python and SQL coding challenges used in every interview, screened 10+ candidates, and set team coding standards'''.split('\n')
p1_all = ''
for line in p1:
    tmp = f"<li>{line}</li>\n"
    p1_all += tmp
print(p1_all)
# Out:
# <li>Designed platform-agnostic agent architecture with abstraction layers for LLM providers (Bedrock, Cortex), data sources (S3, Snowflake Stage, Athena), and deployment targets (EC2, Snowflake containers) — codebase adopted as the baseline for two subsequent production systems without re-architecture</li>
# <li>Mentored team on building for enterprise volatility: how to design modular systems that absorb changing platform mandates, requirements, and deployment constraints rather than requiring rewrites</li>
# <li>Own all technical hiring for the GenAI team: designed Python and SQL coding challenges used in every interview, screened 10+ candidates, and set team coding standards</li>

# %%
p1 = '''Pioneered the company's first production text-to-SQL system on healthcare claims data (hundreds of tables) — coordinating model inference, multi-source retrieval, and domain-specific reasoning across medical code resolution, claim type routing, and per-query business logic 
Developed comprehensive tooling layer: ICD/CPT/NDC code lookup, claims logic arbitration (inpatient vs. outpatient, join selection, calculation rules), and vector-based retrieval for few-shot SQL examples 
Designed the company's first gold-standard evaluation dataset and assessment pipeline for text-to-SQL — establishing the benchmarking methodology and feedback-driven improvement process later scaled to the Provider Performance system
Achieved ~85% accuracy on complex claims queries; ~12.5% adoption among target users, with outputs used directly in weekly executive slide decks and reports'''.split('\n')
p1_all = ''
for line in p1:
    tmp = f"<li>{line}</li>\n"
    p1_all += tmp
print(p1_all)
# Out:
# <li>Pioneered the company's first production text-to-SQL system on healthcare claims data (hundreds of tables) — coordinating model inference, multi-source retrieval, and domain-specific reasoning across medical code resolution, claim type routing, and per-query business logic </li>
# <li>Developed comprehensive tooling layer: ICD/CPT/NDC code lookup, claims logic arbitration (inpatient vs. outpatient, join selection, calculation rules), and vector-based retrieval for few-shot SQL examples </li>
# <li>Designed the company's first gold-standard evaluation dataset and assessment pipeline for text-to-SQL — establishing the benchmarking methodology and feedback-driven improvement process later scaled to the Provider Performance system</li>
# <li>Achieved ~85% accuracy on complex claims queries; ~12.5% adoption among target users, with outputs used directly in weekly executive slide decks and reports</li>
