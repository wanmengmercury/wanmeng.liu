# %%
p1 = '''Architected and deployed end-to-end text-to-SQL agentic system as lead engineer — enabling natural language queries across proprietary provider performance metrics (cost, appropriateness, quality), achieving ~85% accuracy where Snowflake Intelligence scored ~20% and driving strategic platform decision
Built master routing agent orchestrating document retrieval, SQL generation, and guardrails into a single application serving dual audiences: business users who need answers and analysts who need accelerated SQL 
Decomposed text-to-SQL into discrete, debuggable decision points with self-correcting query mechanism; parallelized retrieval reducing response time to <20 seconds versus hours for human analysts
Designed and shipped full-stack application (Python backend, Streamlit & CSS & HTML frontend) — architecture through UI, no dedicated frontend engineer
Led full-stack migration from AWS (Bedrock, Knowledge Base, S3, Athena) to Snowflake-native architecture (Cortex LLM, Cortex Search, embedding models), resolving organizational deadlock on compliance requirements
Built automated evaluation pipeline: GEPA prompt optimization for systematic accuracy improvement, SQL judge reducing evaluation cycles from 2-3 hours to 20 minutes'''.split('\n')
p1_all = ''
for line in p1:
    tmp = f"<li>{line}</li>\n"
    p1_all += tmp
print(p1_all)
# Out:
# <li>Architected and deployed end-to-end text-to-SQL agentic system as lead engineer — enabling natural language queries across proprietary provider performance metrics (cost, appropriateness, quality), achieving ~85% accuracy where Snowflake Intelligence scored ~20% and driving strategic platform decision</li>
# <li>Built master routing agent orchestrating document retrieval, SQL generation, and guardrails into a single application serving dual audiences: business users who need answers and analysts who need accelerated SQL </li>
# <li>Decomposed text-to-SQL into discrete, debuggable decision points with self-correcting query mechanism; parallelized retrieval reducing response time to <20 seconds versus hours for human analysts</li>
# <li>Designed and shipped full-stack application (Python backend, Streamlit & CSS & HTML frontend) — architecture through UI, no dedicated frontend engineer</li>
# ...

# %%
p1 = '''Designed novel fraud detection methodology proving group-level upcoding patterns could be identified from incomplete claims data — reframing a problem the industry typically considers blocked by insufficient clinical detail
Collaborated with chief medical officer to scope approach: built event tables defining 5 clinical traits distinguishing true sepsis from potential upcoding, constructed entirely from bundled claims with incomplete CPT and revenue codes
Developed end-to-end pipeline: vectorized patient event sequences, applied k-means clustering to surface 3 distinct admission patterns, and built LLM agent to translate statistical clusters into actionable narratives
~30% of admissions flagged as "unlikely sepsis"; independent audit by a major insurance company validated findings through manual chart review of 100 hospitals, recovering $1.8M
Sole technical contributor across the full pipeline — event tables, clustering, agent development, pattern interpretation'''.split('\n')
p1_all = ''
for line in p1:
    tmp = f"<li>{line}</li>\n"
    p1_all += tmp
print(p1_all)
# Out:
# <li>Designed novel fraud detection methodology proving group-level upcoding patterns could be identified from incomplete claims data — reframing a problem the industry typically considers blocked by insufficient clinical detail</li>
# <li>Collaborated with chief medical officer to scope approach: built event tables defining 5 clinical traits distinguishing true sepsis from potential upcoding, constructed entirely from bundled claims with incomplete CPT and revenue codes</li>
# <li>Developed end-to-end pipeline: vectorized patient event sequences, applied k-means clustering to surface 3 distinct admission patterns, and built LLM agent to translate statistical clusters into actionable narratives</li>
# <li>~30% of admissions flagged as "unlikely sepsis"; independent audit by a major insurance company validated findings through manual chart review of 100 hospitals, recovering $1.8M</li>
# ...

# %%
p1 = '''Collaborated with CDC and Georgia Department of Public Health on COVID-19 simulations analyzing associations between socioeconomic factors and case/hospitalization/vaccination outcomes across 159 Georgia counties
Delivered findings to mixed technical and policy audiences; results informed cruise ship and K-12 reopening policies'''.split('\n')
p1_all = ''
for line in p1:
    tmp = f"<li>{line}</li>\n"
    p1_all += tmp
print(p1_all)
# Out:
# <li>Collaborated with CDC and Georgia Department of Public Health on COVID-19 simulations analyzing associations between socioeconomic factors and case/hospitalization/vaccination outcomes across 159 Georgia counties</li>
# <li>Delivered findings to mixed technical and policy audiences; results informed cruise ship and K-12 reopening policies</li>
